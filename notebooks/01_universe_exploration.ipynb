# %%
import pandas as pd
from pathlib import Path
from factor_research.data.universe import fetch_current_sp500_members, fetch_sp500_changes, build_membership_spells

CACHE_DIR = Path("/Users/eggs/Developer/factor-research/data/raw/wikipedia")

current = fetch_current_sp500_members(CACHE_DIR, force_refresh=True)
changes = fetch_sp500_changes(CACHE_DIR, force_refresh=True)

# %%
current.head()
# Out:
#   ticker             security             gics_sector date_added
# 0    MMM                   3M             Industrials 1957-03-04
# 1    AOS          A. O. Smith             Industrials 2017-07-26
# 2    ABT  Abbott Laboratories             Health Care 1957-03-04
# 3   ABBV               AbbVie             Health Care 2012-12-31
# 4    ACN            Accenture  Information Technology 2011-07-06

# %%
current.tail()
# Out:
#     ticker            security             gics_sector date_added
# 498    XYL          Xylem Inc.             Industrials 2011-11-01
# 499    YUM         Yum! Brands  Consumer Discretionary 1997-10-06
# 500   ZBRA  Zebra Technologies  Information Technology 2019-12-23
# 501    ZBH       Zimmer Biomet             Health Care 2001-08-07
# 502    ZTS              Zoetis             Health Care 2013-06-21

# %%
current.shape
# Out:
# (503, 4)

# %%
current.dtypes
# Out:
# ticker                    str
# security                  str
# gics_sector               str
# date_added     datetime64[us]
# dtype: object

# %%
current['gics_sector'].value_counts()
# Out:
# gics_sector
# Industrials               80
# Financials                76
# Information Technology    72
# Health Care               59
# Consumer Discretionary    48
# Consumer Staples          36
# Utilities                 31
# Real Estate               31
# Materials                 26
# Communication Services    23
# Energy                    21
# Name: count, dtype: int64

# %%
changes.head()
# Out:
#         date  action ticker                 security  \
# 0 1976-07-01  remove    AYE         Allegheny Energy
# 1 1976-07-01     add    DIS  The Walt Disney Company
# 2 1976-07-01     add    BUD           Anheuser Busch
# 3 1976-07-01  remove    HNG      Houston Natural Gas
# 4 1994-09-30  remove    MCK                 McKesson
#
#                                               reason
# 0  Major restructuring of S&P 500 to have fewer i...
# 1  Major restructuring of S&P 500 to have fewer i...
# 2  Major restructuring of S&P 500 to have fewer i...
# 3  Major restructuring of S&P 500 to have fewer i...
# 4    McKesson sold PCS Health Services to Eli Lilly.

# %%
changes.tail()
# Out:
#           date  action ticker            security  \
# 753 2026-06-02  remove   EPAM        EPAM Systems
# 754 2026-06-22     add   FLEX                Flex
# 755 2026-06-22  remove   POOL    Pool Corporation
# 756 2026-06-22  remove    CPB          Campbell's
# 757 2026-06-22     add   MRVL  Marvell Technology
#
#                             reason
# 753  Market capitalization change.
# 754  Market capitalization change.
# 755  Market capitalization change.
# 756  Market capitalization change.
# 757  Market capitalization change.

# %%
changes.shape
# Out:
# (758, 5)

# %%
changes.groupby(changes.date.dt.year).size()
# Out:
# date
# 1976     4
# 1994     2
# 1997     2
# 1998     6
# 1999     5
# 2000    14
# 2003     2
# 2005     4
# 2006     2
# 2007    22
# 2008    16
# 2009    24
# 2010    22
# 2011    38
# 2012    36
# 2013    38
# 2014    30
# 2015    54
# 2016    59
# 2017    56
# 2018    46
# 2019    48
# 2020    34
# 2021    38
# 2022    36
# 2023    30
# 2024    32
# 2025    38
# 2026    20
# dtype: int64

# %%
changes[changes['ticker'] == 'LEH']
# Out:
#          date  action ticker         security  \
# 75 2008-09-16  remove    LEH  Lehman Brothers
#
#                                    reason
# 75  Lehman Brothers filed for bankruptcy.

# %%
from datetime import date
data = {
    'date': ['Alice', 'Bob', 'Charlie'],
    'action': ['add', 'remove', 'add'], 
    'ticker': ['New York', 'Chicago', 'Los Angeles'],
}

df = pd.DataFrame(data)

date(2020,12,21) == date(2020,10,21)
# Out:
# False

# %%
membership_spells = build_membership_spells(current_members=current, changes=changes)

membership_spells.loc[membership_spells['ticker'] == 'AAPL']
# Out:
# Ticker was added in changes but not present current members; skipping event.
# Ticker seems to have been added to changes twice; skipping event.
# Ticker seems to have been added to changes twice; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker seems to have been added to changes twice; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker seems to have been added to changes twice; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker seems to have been added to changes twice; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker seems to have been added to changes twice; skipping event.
# Ticker seems to have been added to changes twice; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker was added in changes but not present current members; skipping event.
# Ticker seems to have been added to changes twice; skipping event.
# Ticker was added in changes but not present current members; skipping event.
#     ticker start_date end_date
# 377   AAPL        NaT      NaT
